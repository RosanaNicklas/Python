# %% [markdown]
# Pytrends
# Puedo hacer muchas cosas:
# Comparativas por palabras clave:
# Bocadillo, Hamburguesa, Pizza, etc. (en Madrid por ejemplo)
# Caso posible para Restaurantes,
# (nuevas cocinas Fantasma, decidir qué platos elaborar etc.)
# Python, R, Matlab, etc. (En España por ejemplo)

# %% [markdown]
# # Instalo Pytrends

# %%
#!pip install pytrends
#Requests, lxml y Pandas
# Out:
# Requirement already satisfied: pytrends in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.8.0)
# Requirement already satisfied: pandas>=0.25 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pytrends) (1.5.0)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pytrends) (4.9.1)
# Requirement already satisfied: requests>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pytrends) (2.28.1)
# Requirement already satisfied: numpy>=1.20.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (1.23.1)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.0->pytrends) (1.26.12)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)

# %%
# Podría comprobar que instaló correctamente, y su versión
# !pip freeze
 #pytrends==4.7.3
# Out:
# adagio==0.2.4
# aiodns==3.0.0
# aiohttp==3.8.3
# aiohttp-cors==0.7.0
# aiohttp-socks==0.7.1
# aioredis==1.3.1
# aiosignal==1.2.0
# ansi2html==1.8.0
# antlr4-python3-runtime==4.11.1
# anyio==3.6.1
# aplus==0.11.0
# appdirs==1.4.4
# appnope==0.1.3
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# async-timeout==4.0.2
# attrs==21.4.0
# backcall==0.2.0
# backports.zoneinfo==0.2.1
# beautifulsoup4==4.11.1
# blake3==0.3.1
# bleach==5.0.1
# blessed==1.19.1
# bokeh==2.4.3
# boto3==1.24.95
# botocore==1.27.95
# branca==0.5.0
# brewer2mpl==1.4.1
# Brotli==1.0.9
# cachetools==5.2.0
# cchardet==2.1.7
# certifi==2022.9.24
# cffi==1.15.1
# charset-normalizer==2.1.1
# click==8.1.3
# cloudpickle==2.2.0
# colorama==0.4.5
# colorful==0.5.4
# commonmark==0.9.1
# cramjam==2.5.0
# cycler==0.11.0
# dash==2.6.2
# dash-core-components==2.0.0
# dash-html-components==2.0.0
# dash-table==5.0.0
# dask==2022.10.0
# dataclasses==0.6
# debugpy==1.6.2
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.5
# distributed==2022.10.0
# elastic-transport==8.4.0
# elasticsearch==8.4.3
# entrypoints==0.4
# executing==0.8.3
# fake-useragent==0.1.11
# fastapi==0.85.0
# fastjsonschema==2.16.1
# fastparquet==0.8.3
# filelock==3.7.1
# Flask==2.2.2
# Flask-Compress==1.13
# folium==0.12.1.post1
# fonttools==4.34.4
# frozendict==2.3.4
# frozenlist==1.3.1
# fs==2.4.16
# fsspec==2022.8.2
# fugue==0.7.3
# fugue-sql-antlr==0.1.1
# future==0.18.2
# geographiclib==1.52
# geopy==2.2.0
# ggplot==0.11.5
# google-api-core==2.10.2
# google-auth==2.13.0
# googleapis-common-protos==1.56.4
# googletransx==2.4.2
# gpustat==1.0.0
# greenlet==1.1.3.post0
# grpcio==1.50.0
# h11==0.14.0
# h5py==3.7.0
# HeapDict==1.0.1
# hiredis==2.0.0
# html5lib==1.1
# httptools==0.5.0
# idna==3.4
# importlib-metadata==5.0.0
# importlib-resources==5.8.0
# inflection==0.5.1
# ipykernel==6.15.1
# ipython==8.4.0
# ipython-genutils==0.2.0
# ipywebrtc==0.6.0
# ipywidgets==8.0.2
# itsdangerous==2.1.2
# jedi==0.18.1
# Jinja2==3.1.2
# jmespath==1.0.1
# joblib==1.2.0
# jsonschema==4.7.2
# jupyter==1.0.0
# jupyter-bokeh==3.0.5
# jupyter-client==7.3.4
# jupyter-console==6.4.4
# jupyter-contrib-core==0.4.0
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.11.1
# jupyter-dash==0.4.2
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.5.0
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.3
# kiwisolver==1.4.4
# llvmlite==0.39.1
# locket==1.0.0
# lxml==4.9.1
# MarkupSafe==2.1.1
# matplotlib==3.5.2
# matplotlib-inline==0.1.3
# mistune==0.8.4
# mizani==0.8.1
# modin==0.16.1
# modin-spreadsheet==0.1.2
# more-itertools==9.0.0
# msgpack==1.0.4
# multidict==6.0.2
# multitasking==0.0.11
# Nasdaq-Data-Link==1.0.4
# nbclient==0.6.6
# nbconvert==6.5.0
# nbformat==5.4.0
# nest-asyncio==1.5.5
# nltk==3.7
# notebook==6.4.12
# numpy==1.23.1
# nvidia-ml-py==11.495.46
# opencensus==0.11.0
# opencensus-context==0.1.3
# packaging==21.3
# palettable==3.3.0
# pandas==1.5.0
# pandocfilters==1.5.0
# parso==0.8.3
# partd==1.3.0
# patsy==0.5.2
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==9.2.0
# platformdirs==2.5.2
# plotly==5.10.0
# plotnine==0.9.0
# plumbum==1.8.0
# progressbar2==4.1.1
# prometheus-client==0.14.1
# prompt-toolkit==3.0.30
# protobuf==4.21.8
# psutil==5.9.1
# psycopg2-binary==2.9.4
# ptyprocess==0.7.0
# pure-eval==0.2.2
# py-postgresql==1.2.2
# py-spy==0.3.14
# pyarrow==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycares==4.2.2
# pycparser==2.21
# pydantic==1.10.2
# pyerfa==2.0.0.1
# Pygments==2.12.0
# pymongo==4.2.0
# pyparsing==3.0.9
# pyrsistent==0.18.1
# PySocks==1.7.1
# python-dateutil==2.8.2
# python-dotenv==0.21.0
# python-socks==2.0.3
# python-utils==3.3.3
# pytrends==4.8.0
# pytz==2022.1
# PyYAML==6.0
# pyzmq==23.2.0
# qpd==0.3.3
# qtconsole==5.3.1
# QtPy==2.1.0
# Quandl==3.7.0
# ray==1.5.2
# redis==3.5.3
# regex==2022.9.13
# requests==2.28.1
# retrying==1.3.3
# rich==12.6.0
# rpyc==4.1.5
# rsa==4.9
# s3transfer==0.6.0
# schedule==1.1.0
# scipy==1.9.1
# seaborn==0.12.0
# Send2Trash==1.8.0
# six==1.16.0
# sniffio==1.3.0
# sortedcontainers==2.4.0
# soupsieve==2.3.2.post1
# SQLAlchemy==1.4.42
# stack-data==0.3.0
# starlette==0.20.4
# statsmodels==0.13.2
# tabulate==0.9.0
# tblib==1.7.0
# tenacity==8.1.0
# terminado==0.15.0
# textblob==0.17.1
# tinycss2==1.1.1
# toolz==0.12.0
# tornado==6.1
# tqdm==4.64.1
# traitlets==5.3.0
# traittypes==0.2.1
# triad==0.7.0
# -e git+https://github.com/twintproject/twint.git@e7c8a0c764f6879188e5c21e25fb6f1f856a7221#egg=twint
# typing_extensions==4.3.0
# urllib3==1.26.12
# uvicorn==0.18.3
# uvloop==0.17.0
# vaex-core==4.14.0
# virtualenv==20.15.1
# watchfiles==0.18.0
# wcwidth==0.2.5
# webencodings==0.5.1
# websockets==10.3
# Werkzeug==2.2.2
# widgetsnbextension==4.0.3
# xyzservices==2022.9.0
# yarl==1.8.1
# yfinance==0.1.84
# zict==2.2.0
# zipp==3.8.1

# %% [markdown]
# # Importamos nuestras dependencias principales

# %%
# pandas module
import pandas as pd
# pytrends
from pytrends.request import TrendReq
# Matplotlib
import matplotlib.pyplot as plt
# para poder imprimir de forma ordenada listas largas
# (en este caso concreto)
import numpy as np

# %% [markdown]
# # trending_searches

# %% [markdown]
# búsqueda simple

# %%
pytrends = TrendReq(hl='en', tz =360)
pytrends

# %%
pytrends.trending_searches(pn='united_states')
# Out:
#                             0
# 0                    Clippers
# 1         Fetterman-Oz Debate
# 2                  Earthquake
# 3            Champions League
# 4                   Powerball
# 5   RB Leipzig vs Real Madrid
# 6             Brittney Griner
# 7                    Man City
# 8                 Real Madrid
# 9                 Auto Repair
# 10        Benfica vs Juventus
# 11      UEFA Champions League
# 12                        PSG
# 13     Cabinet of Curiosities
# 14               Bradley Beal
# 15                 Katy Perry
# 16                  Barbarian
# 17              Solar eclipse
# 18                 Steve Lacy
# 19              Funeral Homes

# %%
pytrends.trending_searches(pn='france')
# Out:
#                                   0
# 0                      Julien Bayou
# 1                               ZFE
# 2                       Inter Milan
# 3                          Del Arte
# 4                              Puff
# 5          Paris-sg – Maccabi Haïfa
# 6          RB Leipzig – Real Madrid
# 7                Benfica – Juventus
# 8        Dortmund – Manchester City
# 9                          WhatsApp
# 10         Dinamo Zagreb – AC Milan
# 11                 Champions League
# 12                           Roanne
# 13             Séville – Copenhague
# 14                     Harry Potter
# 15        Accident A13 gendarme tué
# 16                    Claudio capeo
# 17  Eintracht Francfort – Marseille
# 18                      Celine Dion
# 19                    Cyril Hanouna

# %%
pytrends.trending_searches(pn='japan')
# Out:
#               0
# 0        日本シリーズ
# 1         オリックス
# 2          プロ野球
# 3   ゴートゥーイート 東京
# 4         ダイヤのA
# 5            CL
# 6          田中秀和
# 7        ティファニー
# 8           スナク
# 9          坂本龍一
# 10     野田佳彦追悼演説
# 11    HEY-SMITH
# 12    MAMA 2022
# 13     高校野球関東大会
# 14         中川大志
# 15         エルピス
# 16        ファイザー
# 17          Ado
# 18      東京国際映画祭
# 19          菊花賞

# %%
#pytrends.trending_searches(pn='china')
# no va

# %%
# pytrends.trending_searches(pn='deutschland')
pytrends.trending_searches(pn='germany')
# Out:
#                                       0
# 0                Russland Ukraine-Krieg
# 1                      Sonnenfinsternis
# 2                              WhatsApp
# 3                       Jugendwort 2022
# 4                                  DAZN
# 5                 UEFA Champions League
# 6   Eintracht Frankfurt gegen Marseille
# 7                              Juventus
# 8                               Chelsea
# 9                            Steinmeier
# 10                      Brittney Griner
# 11                     Harvey Weinstein
# 12                     Champions League
# 13         RB Leipzig gegen Real Madrid
# 14                Sonnenfinsternis 2022
# 15                          Rishi Sunak
# 16                           Kanye West
# 17                        Leslie Jordan
# 18                         Bayern barca
# 19                       Antje Hermenau

# %%
pytrends.trending_searches(pn='united_kingdom')
# Out:
#                              0
# 0           Ireland vs England
# 1               Erling Haaland
# 2                      Burnley
# 3                       Ilford
# 4                WhatsApp Down
# 5             Champions League
# 6                     Man City
# 7         PSG vs Maccabi Haifa
# 8             Suella Braverman
# 9   Celtic vs Shakhtar Donetsk
# 10   RB Leipzig vs Real Madrid
# 11         Benfica vs Juventus
# 12               Solar eclipse
# 13             Jacob Rees-Mogg
# 14      Dinamo Zagreb vs Milan
# 15         Rishi Sunak Cabinet
# 16                 Paul Mullin
# 17              Therese Coffey
# 18               Steve Barclay
# 19       UEFA Champions League

# %%
pytrends.trending_searches(pn='portugal')
# Out:
#                             0
# 0                   Palmeiras
# 1                    Flamengo
# 2                   Barcelona
# 3            Susana Naspolini
# 4                 Liga Europa
# 5                   Tottenham
# 6                     Burnout
# 7                      Sauber
# 8          Guillermo del Toro
# 9                    WhatsApp
# 10  RB Leipzig vs Real Madrid
# 11                      Porto
# 12                   Desporto
# 13                 Kanye West
# 14             Borussia  City
# 15   Homem mais sujo do mundo
# 16                        TVI
# 17                    Chelsea
# 18                 Joao mario
# 19     Sport Lisboa e Benfica

# %%
#pytrends.trending_searches(pn='spain')
# por algun motivo no va

# %% [markdown]
# Ejemplo 1: Pero Mejorando resultados
# Para obtener los mejores resultados:
# debe incluir la fecha.
# el idioma anfitrión (hl),
# la zona horaria (tz)
# y la ubicación geográfica (geo) son entradas opcionales.

# %%
# búsquedas en inglés en EEUU (2020)
pytrends.top_charts(date='2020',
hl='en-US',
tz=360,
geo='US')
# Out:
#                          title exploreQuery
# 0             Election results
# 1                  Coronavirus
# 2                  Kobe Bryant
# 3           Coronavirus update
# 4         Coronavirus symptoms
# 5                         Zoom
# 6  Who is winning the election
# 7                  Naya Rivera
# 8             Chadwick Boseman
# 9                PlayStation 5          PS5

# %%
# búsquedas en español en EEUU (2020)
pytrends.top_charts(date='2020',
hl='es-US',
tz=360,
geo='US')
# Out:
#                          title exploreQuery
# 0             Election results
# 1                  Coronavirus
# 2                  Kobe Bryant
# 3           Coronavirus update
# 4         Coronavirus symptoms
# 5                         Zoom
# 6  Who is winning the election
# 7                  Naya Rivera
# 8             Chadwick Boseman
# 9                PlayStation 5          PS5

# %%
# búsquedas en español en EEUU (2019)
pytrends.top_charts(date='2019',
hl='es',
tz=360,
geo='ES')
# Out:
#                          title exploreQuery
# 0         Elecciones generales
# 1                   Notre Dame
# 2  La caída del Muro de Berlín
# 3       Elecciones municipales
# 4                 Black Friday
# 5             Lotería del Niño
# 6                          Vox
# 7              Metro de Madrid
# 8                  Listeriosis
# 9            Boda Sergio Ramos

# %%
# búsquedas en español en España (2020)
pytrends.top_charts(date='2020',
hl='es',
tz=360,
geo='ES')
# Out:
#              title exploreQuery
# 0      coronavirus
# 1  elecciones eeuu
# 2        classroom
# 3          la liga
# 4      Kobe Bryant
# 5            tigre
# 6             zoom
# 7              nba
# 8        champions
# 9          tiburón

# %%
# pytrends.top_charts(date='2021', hl='es', tz=360, geo='ES')
# IndexError: list index out of range

# %%
# No va
#pytrends.top_charts(date='2020', tz=360, geo='MADRID')

# %% [markdown]
# Buscamos algunas tendencias en España

# %% [markdown]
# # Pytrends

# %%
pytrends = TrendReq(hl='ES',
tz =360)
pytrends

# %%
kw_list = ["bocadillo", "hamburguesa", "pizza"]
kw_list
# Out:
# ['bocadillo', 'hamburguesa', 'pizza']

# %% [markdown]
# Alguna información útil:
# kw_list: una lista de palabras clave para obtener datos (límite de 5 palabras clave a la vez)
# geo: la ubicación geográfica.
# timeframe: el marco de tiempo de interés.

# %%
# Construimos el payload
pytrends.build_payload(kw_list,
timeframe='2015-01-01 2021-01-01',
geo='ES')

# %% [markdown]
# # DataFrame (podríamos enviar datos a un excel / csv

# %%
# Interes A lo largo del tiempo
# Almacenando la información en un DataFrame
df = pytrends.interest_over_time()

# %% [markdown]
# # Información relevante del DataFrame

# %%
df.head(20)
# Out:
#             bocadillo  hamburguesa  pizza  isPartial
# date
# 2015-01-01          2            5     47      False
# 2015-02-01          3            5     42      False
# 2015-03-01          3            6     39      False
# 2015-04-01          3            5     38      False
# 2015-05-01          3            6     40      False
# 2015-06-01          3            6     39      False
# 2015-07-01          3            6     41      False
# 2015-08-01          3            6     45      False
# 2015-09-01          3            6     39      False
# 2015-10-01          3            7     43      False
# 2015-11-01          2            6     43      False
# 2015-12-01          2            6     48      False
# 2016-01-01          3            6     61      False
# 2016-02-01          3            7     58      False
# 2016-03-01          3            7     57      False
# 2016-04-01          3            7     57      False
# 2016-05-01          3            6     48      False
# 2016-06-01          3            6     52      False
# 2016-07-01          3            6     56      False
# 2016-08-01          3            5     51      False

# %%
df.tail()
# Out:
#             bocadillo  hamburguesa  pizza  isPartial
# date
# 2020-09-01          3           10     71      False
# 2020-10-01          3           10     80      False
# 2020-11-01          3           10     79      False
# 2020-12-01          3            8     78      False
# 2021-01-01          3            9     87      False

# %%
len(df)
# Out:
# 73

# %%
df.describe()
# Out:
#        bocadillo  hamburguesa       pizza
# count  73.000000    73.000000   73.000000
# mean    3.013699     7.452055   63.369863
# std     0.390625     1.581500   13.458276
# min     2.000000     5.000000   38.000000
# 25%     3.000000     6.000000   57.000000
# 50%     3.000000     7.000000   63.000000
# 75%     3.000000     8.000000   72.000000
# max     5.000000    12.000000  100.000000

# %% [markdown]
# # Algunas gráficas

# %%
# plot all three trends in same chart
plt.figure(figsize=(12,6))
plt.plot(df.index,df.bocadillo,'k*')
plt.plot(df.index,df.hamburguesa,'r*')
plt.plot(df.index,df.pizza,'b*')
plt.legend(['bocadillo','hamburguesa','pizza'])
plt.show()

# %%
# build list of keywords
kw_list = ["bocadillo", "pizza", "hamburguesa", "kebap"]

# build the payload
pytrends.build_payload(kw_list,
                       cat=None,
                       timeframe='2021-01-01 2021-02-01',
                       geo='ES')

# get the interest over time
df = pytrends.interest_over_time()

# ploteo tendencias de comida over time
plt.figure(figsize=(12,6))
plt.plot(df.index,df.bocadillo,'k*')
plt.plot(df.index,df.pizza,'r*')
plt.plot(df.index,df.hamburguesa,'b*')
plt.plot(df.index,df.kebap,'g*')
plt.legend(['bocadillo','pizza','hamburguesa','kebap'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x126901580>, 'Connection to trends.google.com timed out. (connect timeout=2)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22bocadillo%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%2C+%7B%22keyword%22%3A+%22pizza%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%2C+%7B%22keyword%22%3A+%22hamburguesa%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%2C+%7B%22keyword%22%3A+%22kebap%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%5D%2C+%22category%22%3A+null%2C+%22property%22%3A+%22%22%7D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x126901580>, 'Connection to trends.google.com timed out. (connect timeout=2)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Input In [67], in <cell line: 5>()
#       2 kw_list = ["bocadillo", "pizza", "hamburguesa", "kebap"]
#       4 # build the payload
# ----> 5 pytrends.build_payload(kw_list,
#       6                        cat=None,
#       7                        timeframe='2021-01-01 2021-02-01',
#       8                        geo='ES')
#      10 # get the interest over time
#      11 df = pytrends.interest_over_time()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:183, in TrendReq.build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     181 self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     182 # get tokens
# --> 183 self._tokens()
#     184 return
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:189, in TrendReq._tokens(self)
#     187 """Makes request to Google to get API tokens for interest over time, interest by region and related queries"""
#     188 # make the request and parse the returned json
# --> 189 widget_dicts = self._get_data(
#     190     url=TrendReq.GENERAL_URL,
#     191     method=TrendReq.GET_METHOD,
#     192     params=self.token_payload,
#     193     trim_chars=4,
#     194 )['widgets']
#     195 # order of the json matters...
#     196 first_region_token = True
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:138, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     134     response = s.post(url, timeout=self.timeout,
#     135                       cookies=self.cookies, **kwargs,
#     136                       **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     137 else:
# --> 138     response = s.get(url, timeout=self.timeout, cookies=self.cookies,
#     139                      **kwargs, **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     140 # check if the response contains json and throw an exception otherwise
#     141 # Google mostly sends 'application/json' in the Content-Type header,
#     142 # but occasionally it sends 'application/javascript
#     143 # and sometimes even 'text/javascript
#     144 if response.status_code == 200 and 'application/json' in \
#     145         response.headers['Content-Type'] or \
#     146         'application/javascript' in response.headers['Content-Type'] or \
#    (...)
#     149     # some responses start with garbage characters, like ")]}',"
#     150     # these have to be cleaned before being passed to the json parser
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py:553, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     550 if isinstance(e.reason, ConnectTimeoutError):
#     551     # TODO: Remove this in 3.0.0: see #2811
#     552     if not isinstance(e.reason, NewConnectionError):
# --> 553         raise ConnectTimeout(e, request=request)
#     555 if isinstance(e.reason, ResponseError):
#     556     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22bocadillo%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%2C+%7B%22keyword%22%3A+%22pizza%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%2C+%7B%22keyword%22%3A+%22hamburguesa%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%2C+%7B%22keyword%22%3A+%22kebap%22%2C+%22time%22%3A+%222021-01-01+2021-02-01%22%2C+%22geo%22%3A+%22ES%22%7D%5D%2C+%22category%22%3A+null%2C+%22property%22%3A+%22%22%7D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x126901580>, 'Connection to trends.google.com timed out. (connect timeout=2)'))

# %% [markdown]
# # related topics

# %%
# build the payload
pytrends.build_payload(kw_list=['pizza'],
                       timeframe='2016-01-01 2021-02-01',
                       geo='ES')
# get related topics
df_rt = pytrends.related_topics()
df_rt
# Out:
# {'pizza': {'rising':    value formattedValue                                               link  \
#   0  11050       Breakout  /trends/explore?q=/g/11h0kggp7x&date=2016-01-0...
#   1   2450        +2,450%  /trends/explore?q=/m/020tvm&date=2016-01-01+20...
#   2   1750        +1,750%  /trends/explore?q=/m/06hs2r&date=2016-01-01+20...
#   3    850          +850%  /trends/explore?q=/g/1tfhpm_t&date=2016-01-01+...
#   4    250          +250%  /trends/explore?q=/m/015w7p&date=2016-01-01+20...
#   5    140          +140%  /trends/explore?q=/m/03gq1m&date=2016-01-01+20...
#   6    110          +110%  /trends/explore?q=/m/03ydd_t&date=2016-01-01+2...
#   7     80           +80%  /trends/explore?q=/g/11c5511dg7&date=2016-01-0...
#   8     50           +50%  /trends/explore?q=/m/03clwm&date=2016-01-01+20...
#   9     50           +50%  /trends/explore?q=/m/0fkw3&date=2016-01-01+202...
#
#          topic_mid         topic_title  \
#   0  /g/11h0kggp7x       Cecotec Mambo
#   1      /m/020tvm          Papa Johns
#   2      /m/06hs2r         Whole grain
#   3    /g/1tfhpm_t      Can Pizza Prat
#   4      /m/015w7p         Cauliflower
#   5      /m/03gq1m               Spelt
#   6     /m/03ydd_t  Neapolitan cuisine
#   7  /g/11c5511dg7            Just Eat
#   8      /m/03clwm      Domino's Pizza
#   9       /m/0fkw3               Flour
#
#                                           topic_type
#   0                                            Topic
#   1                               Restaurant company
#   2                                             Food
#   3  Pizza restaurant in El Prat de Llobregat, Spain
#   4                                        Vegetable
#   5                                            Wheat
#   6                                          Cuisine
#   7                                          Company
#   8                               Restaurant company
#   9                                             Food  ,
#   'top':     value formattedValue  hasData  \
#   0     100            100     True
#   1      56             56     True
#   2      16             16     True
#   3      11             11     True
#   4       7              7     True
#   5       3              3     True
#   6       3              3     True
#   7       2              2     True
#   8       2              2     True
#   9       2              2     True
#   10      2              2     True
#   11      2              2     True
#   12      2              2     True
#   13      2              2     True
#   14      1              1     True
#   15      1              1     True
#   16      0             <1     True
#   17      0             <1     True
#   18      0             <1     True
#
#                                                    link      topic_mid  \
#   0   /trends/explore?q=/m/0663v&date=2016-01-01+202...       /m/0663v
#   1   /trends/explore?q=/m/03clwm&date=2016-01-01+20...      /m/03clwm
#   2   /trends/explore?q=/m/0dfxdnc&date=2016-01-01+2...     /m/0dfxdnc
#   3   /trends/explore?q=/m/02qmxxd&date=2016-01-01+2...     /m/02qmxxd
#   4   /trends/explore?q=/m/09cfq&date=2016-01-01+202...       /m/09cfq
#   5   /trends/explore?q=/g/11clt88qt_&date=2016-01-0...  /g/11clt88qt_
#   6   /trends/explore?q=/g/1yg58g4jj&date=2016-01-01...   /g/1yg58g4jj
#   7   /trends/explore?q=/m/088lm&date=2016-01-01+202...       /m/088lm
#   8   /trends/explore?q=/m/07xgrh&date=2016-01-01+20...      /m/07xgrh
#   9   /trends/explore?q=/m/0fkw3&date=2016-01-01+202...       /m/0fkw3
#   10  /trends/explore?q=/m/05vll5&date=2016-01-01+20...      /m/05vll5
#   11  /trends/explore?q=/m/020tvm&date=2016-01-01+20...      /m/020tvm
#   12  /trends/explore?q=/g/11c5511dg7&date=2016-01-0...  /g/11c5511dg7
#   13  /trends/explore?q=/m/05m1lt&date=2016-01-01+20...      /m/05m1lt
#   14  /trends/explore?q=/m/09y2k2&date=2016-01-01+20...      /m/09y2k2
#   15  /trends/explore?q=/m/015w7p&date=2016-01-01+20...      /m/015w7p
#   16  /trends/explore?q=/m/03ydd_t&date=2016-01-01+2...     /m/03ydd_t
#   17  /trends/explore?q=/m/06hs2r&date=2016-01-01+20...      /m/06hs2r
#   18  /trends/explore?q=/m/03gq1m&date=2016-01-01+20...      /m/03gq1m
#
#              topic_title          topic_type
#   0                Pizza                Dish
#   1       Domino's Pizza  Restaurant company
#   2          Pizza dough                Food
#   3            Telepizza  Restaurant company
#   4            Pizza Hut  Restaurant company
#   5          Pizza Móvil               Topic
#   6                Dough           Foodstuff
#   7                Yeast              Fungus
#   8           Ingredient               Topic
#   9                Flour                Food
#   10            Domicile                 Law
#   11          Papa Johns  Restaurant company
#   12            Just Eat             Company
#   13      Pizza delivery               Topic
#   14     Italian cuisine             Cuisine
#   15         Cauliflower           Vegetable
#   16  Neapolitan cuisine             Cuisine
#   17         Whole grain                Food
#   18               Spelt               Wheat  }}

# %% [markdown]
# # related queries

# %%
# build the payload
pytrends.build_payload(kw_list=['pizza'],
                       timeframe='2021-01-01 2021-02-01',
                       geo='ES')
# get related queries
df_rq = pytrends.related_queries()

# display df_rq
print(df_rq)
# Out:
# {'pizza': {'top':                     query  value
# 0           pizza dominos    100
# 1                 dominos     98
# 2              masa pizza     44
# 3           masa de pizza     26
# 4               telepizza     21
# 5         pizza telepizza     21
# 6               pizza hut     16
# 7            pizza casera     13
# 8            pizza receta     12
# 9         pizza thermomix     11
# 10               pizzeria      9
# 11   masa pizza thermomix      8
# 12            horno pizza      8
# 13      pizza a domicilio      7
# 14      masa pizza casera      7
# 15      receta masa pizza      6
# 16        pizza mercadona      6
# 17        masa para pizza      6
# 18                 pizzas      5
# 19   masa de pizza casera      5
# 20     ingredientes pizza      5
# 21    hacer masa de pizza      4
# 22          recetas pizza      4
# 23  ofertas dominos pizza      4
# 24           domino pizza      4, 'rising':                              query  value
# 0                        pizza joy   7950
# 1                        deliveroo   7550
# 2          pizza market sant cugat   6500
# 3         pizza royers tamaraceite   5650
# 4                 seven pizza pego   3900
# 5                 pizza villa rota   1750
# 6          pizza royers vecindario    400
# 7                    pizza vegetal    350
# 8            receta pizza italiana    350
# 9     masa pizza panificadora lidl    350
# 10            dominos pizza mieres    300
# 11  masa pizza con levadura fresca    300
# 12          dominos pizza illescas    250
# 13                pizza house reus    250
# 14               pizza de verduras    250
# 15        dominos pizza granollers    200
# 16                      pizza klam    200
# 17      masa pizza levadura fresca    180
# 18          masa de pizza italiana    180
# 19             masa de pizza mambo    170
# 20   masa pizza integral thermomix    160
# 21                   parking pizza    160
# 22             dominos pizza gijon    150
# 23                    mystic pizza    150
# 24         como hacer pizza casera    140}}

# %% [markdown]
# # Predicción: No la haremos

# %% [markdown]
# Opciones:
# Facebook Prophet
# Arima
# PyaCaret y Auto ML

# %% [markdown]
# # Otro ejemplo..

# %%
# pytrends = TrendReq(hl='en-US', tz=360) para EEUU
pytrends = TrendReq(tz=360,
geo="ES")
pytrends

# %%
# Lista de key words (palabras clave)
kw_list = ["Python", "R", "Matlab", "Julia"]
kw_list
# Out:
# ['Python', 'R', 'Matlab', 'Julia']

# %%
pytrends.build_payload(kw_list,
                       timeframe='2015-01-01 2021-01-01',
                       geo='ES')

# %%
df = pytrends.interest_over_time()
df.head(20)
# Out:
#             Python   R  Matlab  Julia  isPartial
# date
# 2015-01-01       9  71       6     22      False
# 2015-02-01      10  68       7     22      False
# 2015-03-01      11  70       8     20      False
# 2015-04-01      10  65       7     20      False
# 2015-05-01      10  61       8     22      False
# 2015-06-01      10  61       5     23      False
# 2015-07-01      10  66       4     21      False
# 2015-08-01       9  63       3     22      False
# 2015-09-01      11  58       5     20      False
# 2015-10-01      11  65       7     21      False
# 2015-11-01      12  91       8     22      False
# 2015-12-01      11  95       6     36      False
# 2016-01-01      11  68       6     22      False
# 2016-02-01      13  63       6     23      False
# 2016-03-01      13  60       7     22      False
# 2016-04-01      14  64       7     21      False
# 2016-05-01      13  65       7     24      False
# 2016-06-01      13  61       6     21      False
# 2016-07-01      12  58       4     22      False
# 2016-08-01      11  57       3     21      False

# %%
# import matplotlib plotting module to visualize data
import matplotlib.pyplot as plt
# plot all three trends in same chart
plt.figure(figsize=(16,6))
plt.plot(df.index,df.Python,'k*')
plt.plot(df.index,df.R,'r*')
plt.plot(df.index,df.Matlab,'b*')
plt.plot(df.index,df.Julia,'g*')
plt.legend(['Python','R','Matlab', 'Julia'])
plt.show()

# %% [markdown]
# # INTERÉS EN UNA ÉPOCA CONCRETA

# %%
# build list of keywords
kw_list = ["Python", "R", "Matlab", "Julia"]

# build the payload
pytrends.build_payload(kw_list,
                       cat=None,
                       timeframe='2019-01-01 2021-01-01',
                       geo='US')

# get the interest over time
df = pytrends.interest_over_time()

# ploteo tendencia en búsquedas por lenguaje de programación over time
plt.figure(figsize=(16,6))
plt.plot(df.index,df.Python,'k*')
plt.plot(df.index,df.R,'r*')
plt.plot(df.index,df.Matlab,'b*')
plt.plot(df.index,df.Julia,'g*')
plt.legend(['Python','R','Matlab','Julia'])
plt.show()

# %% [markdown]
# Si bien el interés a lo largo del tiempo es interesante,
# es posible que desee utilizar las tendencias de Google para encontrar:
# temas,
# consultas
# o sugerencias relacionados.
# Para hacerlo, puede utilizar los métodos:
# related_topics (),
# related_queries ()
# y Followers ().

# %%
# build the payload
pytrends.build_payload(kw_list=['Python'],
                       timeframe='2018-01-01 2021-01-01',
                       geo='ES')

# get related topics
df_rt = pytrends.related_topics()
print(df_rt)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Input In [89], in <cell line: 7>()
#       2 pytrends.build_payload(kw_list=['Python'],
#       3                        timeframe='2018-01-01 2021-01-01',
#       4                        geo='ES')
#       6 # get related topics
# ----> 7 df_rt = pytrends.related_topics()
#       8 print(df_rt)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:339, in TrendReq.related_topics(self)
#     336 related_payload['tz'] = self.tz
#     338 # parse the returned json
# --> 339 req_json = self._get_data(
#     340     url=TrendReq.RELATED_QUERIES_URL,
#     341     method=TrendReq.GET_METHOD,
#     342     trim_chars=5,
#     343     params=related_payload,
#     344 )
#     346 # top topics
#     347 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:157, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     154     return json.loads(content)
#     155 else:
#     156     # error
# --> 157     raise exceptions.ResponseError(
#     158         'The request failed: Google returned a '
#     159         'response with code {0}.'.format(response.status_code),
#     160         response=response)
#
# ResponseError: The request failed: Google returned a response with code 429.

# %%
# top 5 rising results para la palabra clave Python
print(df_rt['Python']['rising'].head(5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [90], in <cell line: 2>()
#       1 # top 5 rising results para la palabra clave Python
# ----> 2 print(df_rt['Python']['rising'].head(5))
#
# KeyError: 'Python'

# %%
# top 5 top results para la palabra clave Python
print(df_rt['Python']['top'].head(5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [91], in <cell line: 2>()
#       1 # top 5 top results para la palabra clave Python
# ----> 2 print(df_rt['Python']['top'].head(5))
#
# KeyError: 'Python'

# %%
# build the payload
pytrends.build_payload(kw_list=['Python'],
timeframe='2019-01-01 2021-01-01',
geo='US')
# get related queries
df_rq = pytrends.related_queries()
# display df_rq
print(df_rq)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Input In [50], in <cell line: 6>()
#       2 pytrends.build_payload(kw_list=['Python'],
#       3 timeframe='2019-01-01 2021-01-01',
#       4 geo='US')
#       5 # get related queries
# ----> 6 df_rq = pytrends.related_queries()
#       7 # display df_rq
#       8 print(df_rq)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:391, in TrendReq.related_queries(self)
#     388 related_payload['tz'] = self.tz
#     390 # parse the returned json
# --> 391 req_json = self._get_data(
#     392     url=TrendReq.RELATED_QUERIES_URL,
#     393     method=TrendReq.GET_METHOD,
#     394     trim_chars=5,
#     395     params=related_payload,
#     396 )
#     398 # top queries
#     399 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:157, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     154     return json.loads(content)
#     155 else:
#     156     # error
# --> 157     raise exceptions.ResponseError(
#     158         'The request failed: Google returned a '
#     159         'response with code {0}.'.format(response.status_code),
#     160         response=response)
#
# ResponseError: The request failed: Google returned a response with code 429.

# %%
# Finalmente, podemos obtener palabras clave de búsqueda sugeridas
# como se muestra a continuación:

# %%
# get suggestions
df_s = pytrends.suggestions('Python')
# display df_rq
print(np.array(df_s))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x12764a490>, 'Connection to trends.google.com timed out. (connect timeout=2)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/autocomplete/Python?hl=en-US (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12764a490>, 'Connection to trends.google.com timed out. (connect timeout=2)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Input In [82], in <cell line: 2>()
#       1 # get suggestions
# ----> 2 df_s = pytrends.suggestions('Python')
#       3 # display df_rq
#       4 print(np.array(df_s))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:523, in TrendReq.suggestions(self, keyword)
#     520 kw_param = quote(keyword)
#     521 parameters = {'hl': self.hl}
# --> 523 req_json = self._get_data(
#     524     url=TrendReq.SUGGESTIONS_URL + kw_param,
#     525     params=parameters,
#     526     method=TrendReq.GET_METHOD,
#     527     trim_chars=5,
#     528     **self.requests_args
#     529 )['default']['topics']
#     530 return req_json
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytrends/request.py:138, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     134     response = s.post(url, timeout=self.timeout,
#     135                       cookies=self.cookies, **kwargs,
#     136                       **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     137 else:
# --> 138     response = s.get(url, timeout=self.timeout, cookies=self.cookies,
#     139                      **kwargs, **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     140 # check if the response contains json and throw an exception otherwise
#     141 # Google mostly sends 'application/json' in the Content-Type header,
#     142 # but occasionally it sends 'application/javascript
#     143 # and sometimes even 'text/javascript
#     144 if response.status_code == 200 and 'application/json' in \
#     145         response.headers['Content-Type'] or \
#     146         'application/javascript' in response.headers['Content-Type'] or \
#    (...)
#     149     # some responses start with garbage characters, like ")]}',"
#     150     # these have to be cleaned before being passed to the json parser
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py:553, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     550 if isinstance(e.reason, ConnectTimeoutError):
#     551     # TODO: Remove this in 3.0.0: see #2811
#     552     if not isinstance(e.reason, NewConnectionError):
# --> 553         raise ConnectTimeout(e, request=request)
#     555 if isinstance(e.reason, ResponseError):
#     556     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/autocomplete/Python?hl=en-US (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12764a490>, 'Connection to trends.google.com timed out. (connect timeout=2)'))

# %% [markdown]
# # Y otro ejemplo más

# %%
# Solo necesitamos pues ejecutar esto una vez
# el resto de requests usarán la misma sesión
pytrend = TrendReq()
# payload y API tokens.
# solo necesario para interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['pizza', 'kebab'])

# %%
# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
print(interest_over_time_df.head())

# %%
# Interest by Region
interest_by_region_df = pytrend.interest_by_region()
print(interest_by_region_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [83], in <cell line: 2>()
#       1 # Interest by Region
# ----> 2 interest_by_region_df = pytrend.interest_by_region()
#       3 print(interest_by_region_df.head())
#
# NameError: name 'pytrend' is not defined

# %%
# Related Queries,
# returns a dictionary of dataframes
related_queries_dict = pytrend.related_queries()
print(related_queries_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [84], in <cell line: 3>()
#       1 # Related Queries,
#       2 # returns a dictionary of dataframes
# ----> 3 related_queries_dict = pytrend.related_queries()
#       4 print(related_queries_dict)
#
# NameError: name 'pytrend' is not defined

# %%
# Get Google Hot Trends data
trending_searches_df = pytrend.trending_searches()
print(trending_searches_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 2>()
#       1 # Get Google Hot Trends data
# ----> 2 trending_searches_df = pytrend.trending_searches()
#       3 print(trending_searches_df.head())
#
# NameError: name 'pytrend' is not defined

# %%
# Get Google Hot Trends data
today_searches_df = pytrend.today_searches()
print(today_searches_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 2>()
#       1 # Get Google Hot Trends data
# ----> 2 today_searches_df = pytrend.today_searches()
#       3 print(today_searches_df.head())
#
# NameError: name 'pytrend' is not defined

# %%
# Get Google Top Charts
top_charts_df = pytrend.top_charts(2018,
hl='en-US',
tz=300,
geo='GLOBAL')
print(top_charts_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 # Get Google Top Charts
# ----> 2 top_charts_df = pytrend.top_charts(2018,
#       3 hl='en-US',
#       4 tz=300,
#       5 geo='GLOBAL')
#       6 print(top_charts_df.head())
#
# NameError: name 'pytrend' is not defined

# %%
# Get Google Keyword Suggestions
suggestions_dict = pytrend.suggestions(keyword='pizza')
print(np.array(suggestions_dict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 2>()
#       1 # Get Google Keyword Suggestions
# ----> 2 suggestions_dict = pytrend.suggestions(keyword='pizza')
#       3 print(np.array(suggestions_dict))
#
# NameError: name 'pytrend' is not defined
